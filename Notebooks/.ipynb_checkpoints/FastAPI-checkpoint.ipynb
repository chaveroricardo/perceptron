# %%
pip install fastapi uvicorn pymongo pandas numpy scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from skimage.io import imread
from skimage.transform import resize
from pymongo import MongoClient

# %%
# Atlas connection string
CONNECTION_STRING = "mongodb+srv://rchavero:gE4Dv5xGYLaIgWrk@cluster0.8zv3a.mongodb.net/"

# Connect to MongoDB
client = MongoClient(CONNECTION_STRING)

# Access database and collection
db = client['Perceptron']
collection = db['Esophagus']

print("Connected to MongoDB!")
# Out:
# Connected to MongoDB!

# %%
# Read CSV file with image metadata
csv_url = "https://raw.githubusercontent.com/AnIsAsPe/ClassificadorCancerEsofago/master/Datos/ClasesImagenes.csv"
data = pd.read_csv(csv_url, usecols=['image_filename', 'class_number'])

# Display metadata
print(data.head())
# Out:
#   image_filename  class_number
# 0     im_4_0.png             0
# 1    im_21_0.png             0
# 2     im_9_0.png             0
# 3     im_8_0.png             0
# 4    im_15_0.png             0

# %%
import os
from pymongo import MongoClient
from bson.binary import Binary

# Conexión a MongoDB
CONNECTION_STRING = "mongodb+srv://rchavero:gE4Dv5xGYLaIgWrk@cluster0.8zv3a.mongodb.net/"
client = MongoClient(CONNECTION_STRING)
db = client['Perceptron']
collection = db['Esophagus']

# Directorios locales
image_dir = "/Users/rmcm/Downloads/CarpetaImagenes"  # Carpeta con las imágenes originales
vector_dir = "/Users/rmcm/Downloads/CompressedVectors"  # Carpeta con los vectores comprimidos

# Leer archivos y crear documentos para MongoDB
documents = []

for _, row in data.iterrows():
    image_path = os.path.join(image_dir, row['image_filename'])
    vector_path = os.path.join(vector_dir, f"{row['image_filename']}.npz")  # Asumimos que tienen el mismo nombre con extensión .npz

    if not os.path.exists(image_path) or not os.path.exists(vector_path):
        print(f"Advertencia: Faltan datos para {row['image_filename']}.")
        continue

    # Leer imagen original como binario
    with open(image_path, "rb") as f:
        image_binary = Binary(f.read())

    # Leer vector comprimido como binario
    with open(vector_path, "rb") as f:
        vector_binary = Binary(f.read())

    # Crear documento para MongoDB
    document = {
        "filename": row['image_filename'],
        "label": int(row['class_number']),
        "image_binary": image_binary,  # Imagen original en binario
        "compressed_vector_binary": vector_binary  # Vector comprimido en binario
    }
    documents.append(document)

# Insertar los documentos en MongoDB
collection.insert_many(documents)
print(f"Uploaded {len(documents)} documents to MongoDB.")
# Out:
# Uploaded 5063 documents to MongoDB.

# %%
from PIL import Image
from io import BytesIO

# Recuperar un documento
document = collection.find_one({"filename": "im_4_0.png"})

# Reconstruir y mostrar la imagen desde MongoDB
image_binary = document['image_binary']
image = Image.open(BytesIO(image_binary))
image.show()

# %%
# Recuperar un vector comprimido
vector_binary = document['compressed_vector_binary']

# Guardar temporalmente el vector y descomprimirlo
with open("temp_vector.npz", "wb") as f:
    f.write(vector_binary)

vector_data = np.load("temp_vector.npz")['vector']
print(f"Vector shape: {vector_data.shape}")
# Out:
# Vector shape: (16384,)

# %%
import numpy as np
from pymongo import MongoClient
from sklearn.model_selection import train_test_split

# Connect to MongoDB
CONNECTION_STRING = "mongodb+srv://rchavero:gE4Dv5xGYLaIgWrk@cluster0.8zv3a.mongodb.net/"
client = MongoClient(CONNECTION_STRING)
db = client['Perceptron']
collection = db['Esophagus']

# Load all documents from the collection
documents = list(collection.find())

# Prepare features (X) and labels (y)
X = []
y = []

for doc in documents:
    # Load the compressed vector from MongoDB
    compressed_vector_binary = doc['compressed_vector_binary']
    
    # Temporarily save and decompress the vector
    with open("temp_vector.npz", "wb") as f:
        f.write(compressed_vector_binary)
    vector_data = np.load("temp_vector.npz")['vector']
    
    X.append(vector_data)
    y.append(doc['label'])

X = np.array(X)
y = np.array(y)

# Check data shapes
print(f"Shape of X: {X.shape}, Shape of y: {y.shape}")
# Out:
# Shape of X: (5063, 16384), Shape of y: (5063,)

# %% [markdown]
# # Perceptron Model

# %%
# Import necessary libraries
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Initialize and train the Perceptron model
perceptron = Perceptron(max_iter=1000, random_state=0, verbose=False, penalty='l2', alpha=0.000005)
perceptron.fit(X_train, y_train)

# Predictions and decision function for ROC AUC
y_pred_perceptron = perceptron.predict(X_test)
y_proba_perceptron = perceptron.decision_function(X_test)

# Evaluate the Perceptron model
accuracy = accuracy_score(y_test, y_pred_perceptron)
recall = recall_score(y_test, y_pred_perceptron)
precision = precision_score(y_test, y_pred_perceptron)
f1 = f1_score(y_test, y_pred_perceptron)
roc_auc = roc_auc_score(y_test, y_proba_perceptron)

# Display performance metrics
print("Perceptron Performance:")
print(f"Accuracy: {accuracy:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Precision: {precision:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"ROC AUC: {roc_auc:.2f}")

# Confusion Matrix
ConfusionMatrixDisplay.from_estimator(perceptron, X_test, y_test, display_labels=["Healthy", "Cancer"])
plt.title("Confusion Matrix for Perceptron")
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba_perceptron)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Perceptron (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Perceptron')
plt.legend(loc="lower right")
plt.show()
# Out:
# Perceptron Performance:
# Accuracy: 0.76
# Recall: 0.68
# Precision: 0.99
# F1 Score: 0.80
# ROC AUC: 0.93

# %%
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Train the Perceptron model
perceptron = Perceptron(max_iter=1000, random_state=0, verbose=False, penalty='l2', alpha=0.00005)
perceptron.fit(X_train, y_train)

# Calibrate the Perceptron model for probability predictions
calibrated_perceptron = CalibratedClassifierCV(perceptron, cv="prefit")  # Use the trained Perceptron
calibrated_perceptron.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=Perceptron(alpha=5e-05, penalty='l2',
#                                             verbose=False))

# %%
import random
from PIL import Image
from io import BytesIO

# Select a random image document from MongoDB
random_document = random.choice(documents)

# Load the compressed vector for the selected image
compressed_vector_binary = random_document['compressed_vector_binary']

# Temporarily save and decompress the vector
with open("temp_test_vector.npz", "wb") as f:
    f.write(compressed_vector_binary)
test_vector_data = np.load("temp_test_vector.npz")['vector']

# Predict probabilities
probas = calibrated_perceptron.predict_proba([test_vector_data])[0]
prediction = calibrated_perceptron.predict([test_vector_data])[0]

print(f"Testing Image: {random_document['filename']}")
print(f"Prediction: {'Cancer' if prediction == 1 else 'Healthy'}")
print(f"Probability of Cancer: {probas[1] * 100:.2f}%")
print(f"Probability of Healthy: {probas[0] * 100:.2f}%")

# Optional: Display the image
image_binary = random_document['image_binary']
image = Image.open(BytesIO(image_binary))
image.show()
# Out:
# Testing Image: im_72_29.png
# Prediction: Cancer
# Probability of Cancer: 97.79%
# Probability of Healthy: 2.21%

# %% [markdown]
# # Random Forest

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Initialize and train the Random Forest model
random_forest = RandomForestClassifier(random_state=0, n_estimators=100)
random_forest.fit(X_train, y_train)

# Predictions and probability for ROC AUC
y_pred_rf = random_forest.predict(X_test)
y_proba_rf = random_forest.predict_proba(X_test)[:, 1]

# Evaluate the Random Forest model
accuracy = accuracy_score(y_test, y_pred_rf)
recall = recall_score(y_test, y_pred_rf)
precision = precision_score(y_test, y_pred_rf)
f1 = f1_score(y_test, y_pred_rf)
roc_auc = roc_auc_score(y_test, y_proba_rf)

# Display performance metrics
print("Random Forest Performance:")
print(f"Accuracy: {accuracy:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Precision: {precision:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"ROC AUC: {roc_auc:.2f}")

# Confusion Matrix
ConfusionMatrixDisplay.from_estimator(random_forest, X_test, y_test, display_labels=["Healthy", "Cancer"])
plt.title("Confusion Matrix for Random Forest")
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba_rf)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Random Forest (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for Random Forest')
plt.legend(loc="lower right")
plt.show()
# Out:
# Random Forest Performance:
# Accuracy: 0.96
# Recall: 1.00
# Precision: 0.95
# F1 Score: 0.97
# ROC AUC: 0.99

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=0)
rf_model.fit(X_train, y_train)

# Calibrate the Random Forest model
calibrated_rf = CalibratedClassifierCV(rf_model, cv="prefit")  # Use the trained Random Forest
calibrated_rf.fit(X_train, y_train)
# Out:
# CalibratedClassifierCV(cv='prefit',
#                        estimator=RandomForestClassifier(random_state=0))

# %%
# Select a random image document from MongoDB
random_document = random.choice(documents)

# Load the compressed vector for the selected image
compressed_vector_binary = random_document['compressed_vector_binary']

# Temporarily save and decompress the vector
with open("temp_test_vector.npz", "wb") as f:
    f.write(compressed_vector_binary)
test_vector_data = np.load("temp_test_vector.npz")['vector']

# Predict probabilities
probas = calibrated_rf.predict_proba([test_vector_data])[0]
prediction = calibrated_rf.predict([test_vector_data])[0]

print(f"Testing Image: {random_document['filename']}")
print(f"Prediction: {'Cancer' if prediction == 1 else 'Healthy'}")
print(f"Probability of Cancer: {probas[1] * 100:.2f}%")
print(f"Probability of Healthy: {probas[0] * 100:.2f}%")
# Out:
# Testing Image: im_242_31.png
# Prediction: Healthy
# Probability of Cancer: 6.86%
# Probability of Healthy: 93.14%

# %% [markdown]
# # Linear Kernel

# %%
# Import necessary libraries
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Sample a subset of the training data (e.g., 20% of the original training set)
X_train_small, _, y_train_small, _ = train_test_split(X_train, y_train, test_size=0.8, random_state=42)

# Initialize and train the SVC model with linear kernel on the smaller dataset
svc_model = SVC(kernel='linear', random_state=42, probability=True)
svc_model.fit(X_train_small, y_train_small)

# Predictions and probability for ROC AUC
y_pred_svc = svc_model.predict(X_test)
y_proba_svc = svc_model.predict_proba(X_test)[:, 1]

# Evaluate the SVC model
accuracy = accuracy_score(y_test, y_pred_svc)
recall = recall_score(y_test, y_pred_svc)
precision = precision_score(y_test, y_pred_svc)
f1 = f1_score(y_test, y_pred_svc)
roc_auc = roc_auc_score(y_test, y_proba_svc)

# Display performance metrics
print("SVC with Linear Kernel (Subset Training) Performance:")
print(f"Accuracy: {accuracy:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Precision: {precision:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"ROC AUC: {roc_auc:.2f}")

# Confusion Matrix
ConfusionMatrixDisplay.from_estimator(svc_model, X_test, y_test, display_labels=["Healthy", "Cancer"])
plt.title("Confusion Matrix for SVC with Linear Kernel (Subset Training)")
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_proba_svc)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'SVC with Linear Kernel (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for SVC with Linear Kernel (Subset Training)')
plt.legend(loc="lower right")
plt.show()
# Out:
# SVC with Linear Kernel (Subset Training) Performance:
# Accuracy: 0.81
# Recall: 0.83
# Precision: 0.90
# F1 Score: 0.86
# ROC AUC: 0.87

# %%
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

# Train the Linear SVM model
svm_model = LinearSVC(max_iter=1000, random_state=0)
svm_model.fit(X_train, y_train)

# Calibrate the Linear SVM model
calibrated_svm = CalibratedClassifierCV(svm_model, cv="prefit")  # Use the trained Linear SVM
calibrated_svm.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
# Select a random image document from MongoDB
random_document = random.choice(documents)

# Load the compressed vector for the selected image
compressed_vector_binary = random_document['compressed_vector_binary']

# Temporarily save and decompress the vector
with open("temp_test_vector.npz", "wb") as f:
    f.write(compressed_vector_binary)
test_vector_data = np.load("temp_test_vector.npz")['vector']

# Predict probabilities
probas = calibrated_svm.predict_proba([test_vector_data])[0]
prediction = calibrated_svm.predict([test_vector_data])[0]

print(f"Testing Image: {random_document['filename']}")
print(f"Prediction: {'Cancer' if prediction == 1 else 'Healthy'}")
print(f"Probability of Cancer: {probas[1] * 100:.2f}%")
print(f"Probability of Healthy: {probas[0] * 100:.2f}%")

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score

# Evaluate Random Forest
rf_y_pred = calibrated_rf.predict(X_test)
rf_y_proba = calibrated_rf.predict_proba(X_test)[:, 1]
rf_accuracy = accuracy_score(y_test, rf_y_pred)
rf_auc = roc_auc_score(y_test, rf_y_proba)
print(f"Random Forest - Accuracy: {rf_accuracy:.2f}, ROC AUC: {rf_auc:.2f}")

# Evaluate Linear SVM
svm_y_pred = calibrated_svm.predict(X_test)
svm_y_proba = calibrated_svm.predict_proba(X_test)[:, 1]
svm_accuracy = accuracy_score(y_test, svm_y_pred)
svm_auc = roc_auc_score(y_test, svm_y_proba)
print(f"Linear SVM - Accuracy: {svm_accuracy:.2f}, ROC AUC: {svm_auc:.2f}")

# Evaluate Perceptron
perc_y_pred = calibrated_perceptron.predict(X_test)
perc_y_proba = calibrated_perceptron.predict_proba(X_test)[:, 1]
perc_accuracy = accuracy_score(y_test, perc_y_pred)
perc_auc = roc_auc_score(y_test, perc_y_proba)
print(f"Perceptron - Accuracy: {perc_accuracy:.2f}, ROC AUC: {perc_auc:.2f}")
